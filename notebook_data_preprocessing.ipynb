# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# ### Data Customer

# %%
customers_df = pd.read_csv("/content/data/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# ### Data Order

# %%
orders_df = pd.read_csv("/content/data/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ### Data Order Item

# %%
order_items_df = pd.read_csv("/content/data/order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# ### Data Product

# %%
products_df = pd.read_csv("/content/data/products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# ### Data Seller

# %%
sellers_df = pd.read_csv("/content/data/sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Data Product Translation

# %%
product_name_df = pd.read_csv("/content/data/product_category_name_translation.csv")
product_name_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ### Data Location

# %%
location_df = pd.read_csv("/content/data/geolocation_dataset.csv")
location_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ## Assessing Data

# %% [markdown]
# ### Assess Data Customer

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# ### Assess Data Order

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-08-02 12:06:07  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# ### Assess Data Order Items

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### Assess Data Product

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# ### Assess Data Seller

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sellers_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### Assess Data Product Name

# %%
product_name_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_name_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_name_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
product_name_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ### Assess Data Location

# %%
location_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
location_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print("Jumlah duplikasi zip code:", location_df.duplicated(subset=['geolocation_zip_code_prefix']).sum())
# Out:
# Jumlah duplikasi zip code: 981148

# %%
location_df[location_df.duplicated(subset=['geolocation_zip_code_prefix'], keep=False)]
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Cleaning Data Customer

# %%
customers_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# ### Cleaning Data Order

# %%
orders_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders_df.order_approved_at.isna().value_counts()
# Out:
# order_approved_at
# False    99281
# True       160
# Name: count, dtype: int64

# %%
# Mengisi data order_approved_at na menjadi order_delivered_carrier_date
orders_df['order_approved_at'] = orders_df['order_approved_at']
orders_df['order_delivered_carrier_date'] = orders_df['order_delivered_carrier_date']

# Declare kondisi: order_approved_at masih NA AND order_status == 'delivered' AND order_delivered_carrier_date NOT NA
condition = (
    orders_df['order_approved_at'].isna() &
    (orders_df['order_status'] == 'delivered') &
    orders_df['order_delivered_carrier_date'].notna()
)

orders_df['order_approved_at'] = np.where(
    condition,
    orders_df['order_delivered_carrier_date'],
    orders_df['order_approved_at']
)

# %%
###Convert from object to datetime
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99295 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
##Checking result fill data order_status delivered dan order_approved_at isna
orders_df[(orders_df.order_status == 'delivered') & (orders_df.order_approved_at.isna())].order_status.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ### Cleaning Data Order Item

# %%
order_items_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_items_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
#Convert from object to datetime
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# ### Cleaning Data Product

# %%
products_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
products_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df.dropna(inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ### Cleaning Data Seller

# %%
sellers_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sellers_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# ### Cleaning Data Product Name

# %%
product_name_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
product_name_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", product_name_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
product_name_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# ### Cleaning Data Location

# %%
location_df.duplicated().sum()
# Out:
# np.int64(261831)

# %%
location_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", location_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Jumlah duplikasi zip code:", location_df.duplicated(subset=['geolocation_zip_code_prefix']).sum())
# Out:
# Jumlah duplikasi zip code: 719317

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### EDA Data Customer

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 49375  e2fc32c48b3f82c468173ca19ba095fa  94bc451b62bb859e277332eefeb99937
# 24729  98fdb7a0ffab98ac4555b9e45387ca13  2a2c5191ab8142cb20a9398971179c32
# 75645  3ef8b5021ce1e54df184202310c4fcb8  dc0b888e7569dd142a2dbeeeccc415ad
# 90704  04ab012a558c5d12ae6037840f85a860  4ce627d55383d1d22fb03e7555cbdc50
# 44852  86449fa8124082cf35a0555fc351f631  0b22bdc11a543726e030cfb5ea5757c6
#
#        customer_zip_code_prefix   customer_city customer_state
# 49375                     20521  rio de janeiro             RJ
# 24729                     78050          cuiaba             MT
# 75645                     30140  belo horizonte             MG
# 90704                      3568       sao paulo             SP
# 44852                     48605    paulo afonso             BA

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.customer_unique_id.is_unique
# Out:
# False

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# agisse                1
# vieiras               1
# bertopolis            1
# abadiania             1
# xexeu                 1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### EDA Data Order

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 79969  0acd987fec172c76297f6aadad48c67a  836ac53e072a95b5b18cbaa4a4f67f7e
# 53696  49afe75c3c09b9e94e1456ffa5e67ff4  09ca2b8e58d607103af7401f7a3a0299
# 14211  ea33aded94976ddb4b9ff4eda6c2eac9  32a81f532a1fbf51f944327bfbc52152
# 67465  892336b9ce0d1f033165460c45e1048e  3f118d3879be515060d11c8f6c2318b1
# 20672  445aaad4cce346818af0ce07050bf4fa  4e11a9e505a8addbba778b9614e0055c
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 79969    delivered      2018-07-28 20:21:33 2018-07-28 20:35:13
# 53696    delivered      2018-01-13 11:42:12 2018-01-13 11:50:27
# 14211    delivered      2017-11-21 17:34:43 2017-11-21 17:48:28
# 67465    delivered      2018-05-06 23:04:37 2018-05-08 19:35:14
# 20672    delivered      2017-11-13 17:03:12 2017-11-13 17:30:33
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 79969          2018-07-30 15:07:00           2018-08-01 19:42:46
# ...

# %%
delivery_carrier_time = orders_df["order_delivered_carrier_date"] - orders_df["order_approved_at"]
delivery_carrier_time = delivery_carrier_time.apply(lambda x: x.total_seconds())
orders_df["delivery_carrier_time_in_day"] = abs(round(delivery_carrier_time/86400))

delivery_customer_time = orders_df["order_delivered_customer_date"] - orders_df["order_approved_at"]
delivery_customer_time = delivery_customer_time.apply(lambda x: x.total_seconds())
orders_df["delivery_customer_time_in_day"] = abs(round(delivery_customer_time/86400))

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 64450  81cb17fa8652482186e8184e2a418057  540cd4c00e0b5bf5252538c02e379d24
# 66677  df926b7d1f6199f57548358c93ec9f39  1adb89d4cb64aba663638417c802dde1
# 11472  8d5af908ce8ffa721a9f665abb660200  f587020fb390d4db881c59e50b0ef9e9
# 97589  4553e6bea248714596b270fa8e67e0a0  5478040f977215fe64805033d2e8612a
# 57437  3ae6c164f9e4222b57e95c67ce981118  4d184b2d4fcbc123ce36c25707636477
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 64450    delivered      2017-03-01 21:45:32 2017-03-01 21:55:18
# 66677    delivered      2018-02-12 11:38:27 2018-02-12 11:50:35
# 11472    delivered      2017-05-27 13:30:08 2017-05-27 13:42:19
# 97589    delivered      2018-05-26 13:17:52 2018-05-26 13:38:15
# 57437    delivered      2018-06-08 05:46:58 2018-06-12 04:35:52
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 64450          2017-03-02 08:05:26           2017-03-13 08:38:01
# ...

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
orders_df[orders_df["delivery_customer_time_in_day"] < 0]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, delivery_carrier_time_in_day, delivery_customer_time_in_day]
# Index: []

# %%
orders_df.delivery_customer_time_in_day.hist(bins=5)

# Add Title, X Label, dan Y Label
plt.title("Distribusi Waktu Pengiriman ke Pelanggan", fontsize=14, fontweight='bold')
plt.xlabel("Waktu Pengiriman (Hari)", fontsize=12)
plt.ylabel("Jumlah Pesanan (Frequency)", fontsize=12)
plt.show()

# %%
customers_df["status"] = np.where(
    customers_df["customer_id"].isin(orders_df["customer_id"]),
    "Active",
    "Non Active"
)

customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 17439  80bf2dc073c61bbc818115f50bf8cb15  f3f0aa7cde3f96c260edbc77fc23b41b
# 86034  f59a170a57d7888bb0757b74e7dc53d3  df1c003ed16d85d02c98e36c7c575246
# 81739  49a6ae8a95c6a78d90945b983ab1ecfc  fb7e29c65321441231990afc201c1b14
# 56063  7adb5b6a71b330eb4b3027a470fe74b5  0c39cc8984e30ac517c69a6671be71a7
# 90615  e286acbf69751918e6e445bc1e8f07fc  a44636f3316d0114566918bd02ef58bd
#
#        customer_zip_code_prefix  customer_city customer_state  status
# 17439                     88025  florianopolis             SC  Active
# 86034                     92027         canoas             RS  Active
# 81739                      4107      sao paulo             SP  Active
# 56063                     49075        aracaju             SE  Active
# 90615                      4131      sao paulo             SP  Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Join between Data Customer and Order

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %% [markdown]
# ### EDA Product

# %%
products_df.sample(10)
# Out:
#                              product_id product_category_name  \
# 11865  4c8105db34ad803d251bdd2b08ee0c24             papelaria
# 6746   42ebb92b7f9bb084077e921ee7e40199         esporte_lazer
# 15781  d882625606363a3200e0f9fee9452105          beleza_saude
# 14881  97e03a28b0808a684c834e7e004ba11f         esporte_lazer
# 21519  48ece3b2abc4abd9d02f45aca7c3476f         esporte_lazer
# 9164   85e8e8aad6ad12d67c21300379760196    ferramentas_jardim
# 32217  e8f732eea94996831b9af41525a9ce3d             telefonia
# 6053   f011deae0b381d8abd76d0ee747370fb       cama_mesa_banho
# 20760  3e8fca04d24eff0e2177d6157127ed70      moveis_decoracao
# 28843  40161099308e1f5f784d57e2b88b31b5          beleza_saude
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 11865                 46.0                       286.0                 3.0
# 6746                  59.0                       432.0                 6.0
# ...

# %%
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32340                 32340
# unique                             32340                    73
# top     106392145fca363410d287a815be6de4       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32340.000000                32340.000000        32340.000000
# ...

# %%
products_df.sort_values(by="product_weight_g", ascending=False)
# Out:
#                              product_id product_category_name  \
# 25166  26644690fde745fc4654719c3904e1db       cama_mesa_banho
# 7535   9dfef86fb34051388a7263a31642386c          beleza_saude
# 7422   bbc5419bc92d76e27795c9ec2c233c64          beleza_saude
# 17914  616c497aa9cc2d4ce93eb380cf5cc121       cama_mesa_banho
# 17993  f6a84928571f68635beb0f5c9333c6f3         esporte_lazer
# ...                                 ...                   ...
# 16181  5837bba0ce6e35e6f2dc5c3e223e3276      moveis_decoracao
# 32079  e673e90efa65a5409ff4196c038bb5af       cama_mesa_banho
# 9769   81781c0fed9fe1ad6e8c81fca1e1cb08       cama_mesa_banho
# 13683  8038040ee2a71048d4bdbbdc985b69ab       cama_mesa_banho
# 14997  36ba42dd187055e1fbe943b2d11430ca       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 25166                 59.0                       534.0                 1.0
# ...

# %%
products_df.groupby(by="product_category_name").agg({
    "product_id": "nunique",
    "product_photos_qty": "sum",
    "product_weight_g":  ["min", "max"]
})
# Out:
#                           product_id product_photos_qty product_weight_g  \
#                              nunique                sum              min
# product_category_name
# agro_industria_e_comercio         74              171.0             50.0
# alimentos                         82              159.0             75.0
# alimentos_bebidas                104              197.0             50.0
# artes                             55              119.0            100.0
# artes_e_artesanato                19               57.0            100.0
# ...                              ...                ...              ...
# sinalizacao_e_seguranca           93              231.0            100.0
# tablets_impressao_imagem           9               27.0            100.0
# telefonia                       1134             3129.0             50.0
# telefonia_fixa                   116              347.0             50.0
# ...

# %% [markdown]
# ### EDA Order Item

# %%
order_items_df.sample(10)
# Out:
#                                order_id  order_item_id  \
# 68183  9bdc00acb04f677adc8329b932122fd6              1
# 5934   0d72ea72bb291e23fc4da4324144fe24              1
# 34030  4cfe0eee95cf16affb0b1b647b379e51              1
# 12359  1c08c2e119666d04a13e375e3156ad5f              1
# 17451  27fb2154c341bbc730063b1d16844616              1
# 62932  8fac4937d08ac74197a48a70c5bc1245              1
# 81260  b8b2320bc7303abbc19c6976fe8b2fd6              2
# 92241  d1537836c453f9672f80c422d1af8cab              2
# 43054  61fb2aed86c91b61373a6d410b30a860              2
# 86482  c46a116ac9c84425011f5e56acb66c85              1
#
#                              product_id                         seller_id  \
# 68183  422879e10f46682990de24d770e7f83d  1f50f920176fa81dab994f9023523100
# 5934   b11cfc408f43a71b16c2288e79172244  432c37c9dfba871172ec162e20118b8c
# 34030  7dac8901a50cf3317d5372cbd3186ecd  6560211a19b47992c3666cc44a7e94c0
# ...

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# ### Join Between Data Product and Order and Order Item

# %%
customers_orders_order_items_df = pd.merge(
    left=orders_customers_df,
    right=order_items_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers_orders_order_items_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
products_orders_order_items_df = pd.merge(
    left=customers_orders_order_items_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
products_orders_order_items_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
products_orders_order_items_name_df = pd.merge(
    left=products_orders_order_items_df,
    right=product_name_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
products_orders_order_items_name_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
products_orders_order_items_name_df.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "freight_value": "sum",
    "price": "sum"
})
# Out:
#                                                    freight_value   price
# customer_city       product_category_name_english
# abadia dos dourados books_general_interest                 18.38   39.90
#                     cool_stuff                             20.63  199.00
#                     sports_leisure                         15.59  120.00
# abadiania           small_appliances                       75.53  949.99
# abaete              baby                                   17.70   65.00
# ...                                                          ...     ...
# ze doca             food_drink                             38.00   65.00
#                     garden_tools                           26.61   39.90
#                     musical_instruments                    49.04  359.00
#                     sports_leisure                         38.60  149.90
# zortea              computers_accessories                  20.98   69.90
#
# [25199 rows x 2 columns]

# %%
products_orders_order_items_name_df.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "freight_value": "sum",
    "price": "sum"
})
# Out:
#                                               freight_value    price
# customer_state product_category_name_english
# AC             auto                                  120.93   540.98
#                baby                                  174.13   697.84
#                bed_bath_table                        157.51   567.70
#                books_general_interest                123.71   633.80
#                christmas_supplies                     60.95    69.90
# ...                                                     ...      ...
# TO             sports_leisure                       1309.99  5144.32
#                stationery                             73.80   276.80
#                telephony                             627.34  1268.12
#                toys                                  423.96  1864.15
#                watches_gifts                         950.02  5446.89
#
# [1356 rows x 2 columns]

# %%
all_datas = pd.merge(
    left=products_orders_order_items_name_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
products_orders_order_items_name_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# s_columns = ['customer_id', 'customer_city', 'customer_state', 'order_status', 'order_id', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_customer_date', 'delivery_customer_time_in_day', 'product_category_name_english', 'price', 'freight_value', 'product_weight_g']

all_data = all_datas
all_data.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
all_data.to_csv("all_data.csv", index=False)

# %%
all_data.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum",
    "product_weight_g": "sum"
})
# Out:
#                                                     price  freight_value  \
# customer_city       product_category_name_english
# abadia dos dourados books_general_interest          39.90          18.38
#                     cool_stuff                     199.00          20.63
#                     sports_leisure                 120.00          15.59
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
# ...                                                   ...            ...
# ze doca             food_drink                      65.00          38.00
#                     garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#                     sports_leisure                 149.90          38.60
# zortea              computers_accessories           69.90          20.98
#
# ...

# %%
all_data.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum",
    "product_weight_g": "sum"
})
# Out:
#                                                 price  freight_value  \
# customer_state product_category_name_english
# AC             auto                            540.98         120.93
#                baby                            697.84         174.13
#                bed_bath_table                  567.70         157.51
#                books_general_interest          633.80         123.71
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 5144.32        1309.99
#                stationery                      276.80          73.80
#                telephony                      1268.12         627.34
#                toys                           1864.15         423.96
#                watches_gifts                  5446.89         950.02
#
#                                               product_weight_g
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Bagaimana Penyebaran/Distribusi Order Status yang Ada?

# %%
all_data.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
all_data.groupby(by=["order_status"]).agg({
    "order_id": "count",
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#               order_id        price  freight_value
# order_status
# approved             3       209.60          31.48
# canceled           706     95235.27       10650.45
# created              5         0.00           0.00
# delivered       110197  13221498.11     2198275.64
# invoiced           361     61526.37        7462.38
# processing         357     60439.22        8954.89
# shipped           1186    150727.44       26401.90
# unavailable        610      2007.69         132.80

# %%
status_counts = all_data['order_status'].value_counts()
plt.figure(figsize=(10, 5))
ax = status_counts.plot(kind='barh', color='#4C72B0')

plt.title('Distribusi Status Pemenuhan Pesanan', fontsize=12, fontweight='bold')
plt.xlabel('Jumlah Pesanan', fontsize=10)
plt.ylabel('Order Status', fontsize=10)
plt.gca().invert_yaxis()

for i, v in enumerate(status_counts):
    pct = (v / len(all_data)) * 100
    ax.text(v + 1000, i, f"{v:,} ({pct:.2f}%)", va='center', fontsize=9)

plt.xlim(0, max(status_counts) * 1.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bagaimana Performa Penjualan dan Revenue dalam Beberapa Bulan Terakhir?

# %%
monthly_orders_df = all_data.resample(rule='ME', on='order_purchase_timestamp').agg({
    "order_id": "count",
    "price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)

monthly_orders_df
# Out:
#    order_purchase_timestamp  order_count     revenue
# 0                   2016-09            7      267.36
# 1                   2016-10          379    49507.66
# 2                   2016-11            0        0.00
# 3                   2016-12            1       10.90
# 4                   2017-01          966   120312.87
# 5                   2017-02         1998   247303.02
# 6                   2017-03         3041   374344.30
# 7                   2017-04         2697   359927.23
# 8                   2017-05         4176   506071.14
# 9                   2017-06         3611   433038.60
# 10                  2017-07         4576   498031.48
# 11                  2017-08         4948   573971.68
# 12                  2017-09         4873   624401.69
# 13                  2017-10         5385   664219.43
# 14                  2017-11         8758  1010271.37
# 15                  2017-12         6357   743914.17
# 16                  2018-01         8257   950030.36
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_purchase_timestamp"],
    monthly_orders_df["order_count"],
    marker='o',
    linewidth=2,
    color="#72BCD4"
)
plt.title("Number of Orders per Year-Month in Brazil Real (R$)", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=45, ha='right')
plt.yticks(fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_purchase_timestamp"],
    monthly_orders_df["revenue"],
    marker='o',
    linewidth=2,
    color="#72BCD4"
)
plt.title("Total Revenue per per Year-Month in Brazil Real (R$)", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=45, ha='right')
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Produk apa yang paling banyak dan paling sedikit terjual?

# %%
sum_order_items_df = all_data.groupby("product_category_name_english").order_id.count().sort_values(ascending=False).reset_index()
sum_order_items_df.head(10)
# Out:
#   product_category_name_english  order_id
# 0                bed_bath_table     11115
# 1                 health_beauty      9670
# 2                sports_leisure      8641
# 3               furniture_decor      8334
# 4         computers_accessories      7827
# 5                    housewares      6964
# 6                 watches_gifts      5991
# 7                     telephony      4545
# 8                  garden_tools      4347
# 9                          auto      4235

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x="order_id",
    y="product_category_name_english",
    data=sum_order_items_df.head(5),
    hue="product_category_name_english",
    palette=colors,
    ax=ax[0]
)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(
    x="order_id",
    y="product_category_name_english",
    data=sum_order_items_df.sort_values(by="order_id", ascending=True).head(5),
    hue="product_category_name_english",
    palette=colors,
    ax=ax[1]
)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Top 5 Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# ### Seller City Mana yang Menghasilkan Revenue Terbesar pada tahun 2017

# %%
sum_price_per_seller_city_df = all_data.groupby("seller_city").price.sum().sort_values(ascending=False).reset_index()
sum_price_per_seller_city_df.head(10)
# Out:
#         seller_city       price
# 0         sao paulo  2702878.14
# 1          ibitinga   624592.94
# 2          curitiba   470759.82
# 3    rio de janeiro   358413.59
# 4         guarulhos   329494.38
# 5    ribeirao preto   275976.44
# 6   itaquaquecetuba   230568.12
# 7           guariba   229472.63
# 8       santo andre   228561.60
# 9  lauro de freitas   225525.05

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x="price",
    y="seller_city",
    data=sum_price_per_seller_city_df.head(5),
    hue="seller_city",
    palette=colors,
    ax=ax[0]
)
ax[0].set_ylabel(None)
ax[0].set_xlabel("Total Revenue (R$)")
ax[0].set_title("Best Seller City", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(
    x="price",
    y="seller_city",
    data=sum_price_per_seller_city_df.sort_values(by="price", ascending=True).head(5),
    hue="seller_city",
    palette=colors,
    ax=ax[1]
)
ax[1].set_ylabel(None)
ax[1].set_xlabel("Total Revenue (R$)")
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Seller City", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

formatter = ticker.FuncFormatter(lambda x, _: f'{x:,.0f}')
ax[0].xaxis.set_major_formatter(formatter)
ax[1].xaxis.set_major_formatter(formatter)

plt.suptitle("Top 5 Best and Worst Revenue Based On Seller City", fontsize=20)
plt.show()

# %% [markdown]
# ### RFM

# %%
rfm_df = all_data.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max",
    "order_id": "nunique",
    "price": "sum"
})
rfm_df.columns = ["customer_id", "max_order_purchase_timestamp", "frequency", "monetary"]
rfm_df.head()

# %%
rfm_df["max_order_purchase_timestamp"] = rfm_df["max_order_purchase_timestamp"].dt.date
recent_date = orders_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_purchase_timestamp"].apply(lambda x: (recent_date - x).days)
rfm_df.head()

# %%
rfm_df.drop("max_order_purchase_timestamp", axis=1, inplace=True)
rfm_df.head()

# %%
rfm_df.describe()

# %%
rfm_df.sort_values(by="recency", ascending=True).head(5)

# %%
rfm_df.sort_values(by="frequency", ascending=False).head(5)

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency",
            x="customer_id",
            hue="customer_id",
            legend=False,
            data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors,
            ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency",
            x="customer_id",
            hue="customer_id",
            legend=False,
            data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors,
            ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary",
            x="customer_id",
            hue="customer_id",
            legend=False,
            data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors,
            ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %%
rfm_df['r_rank'] = rfm_df['recency'].rank(ascending=False)
rfm_df['f_rank'] = rfm_df['frequency'].rank(ascending=True)
rfm_df['m_rank'] = rfm_df['monetary'].rank(ascending=True)

rfm_df.head()

# %%
rfm_df['r_rank_norm'] = (rfm_df['r_rank']/rfm_df['r_rank'].max())*100
rfm_df['f_rank_norm'] = (rfm_df['f_rank']/rfm_df['f_rank'].max())*100
rfm_df['m_rank_norm'] = (rfm_df['m_rank']/rfm_df['m_rank'].max())*100

rfm_df.drop(columns=['r_rank', 'f_rank', 'm_rank'], inplace=True)

rfm_df.head()

# %%
rfm_df['RFM_score'] = 0.15*rfm_df['r_rank_norm']+0.28 * \
    rfm_df['f_rank_norm']+0.57*rfm_df['m_rank_norm']
rfm_df['RFM_score'] *= 0.05
rfm_df = rfm_df.round(2)
rfm_df[['customer_id', 'RFM_score']].head(5)

# %%
rfm_df["customer_segment"] = np.where(
    rfm_df['RFM_score'] > 4.5, "Top customers", (np.where(
        rfm_df['RFM_score'] > 4, "High value customer",(np.where(
            rfm_df['RFM_score'] > 3, "Medium value customer", np.where(
                rfm_df['RFM_score'] > 1.6, 'Low value customers', 'lost customers'))))))

rfm_df[['customer_id', 'RFM_score', 'customer_segment']].head(20)

# %%
customer_segment_df = rfm_df.groupby(by="customer_segment", as_index=False).customer_id.nunique()
customer_segment_df

# %%
customer_segment_df['customer_segment'] = pd.Categorical(customer_segment_df['customer_segment'], [
    "lost customers", "Low value customers", "Medium value customer",
    "High value customer", "Top customers"
])

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x="customer_id",
    y="customer_segment",
    hue="customer_id",
    legend=False,
    data=customer_segment_df.sort_values(by="customer_segment", ascending=False),
    palette=colors_
)
plt.title("Number of Customer for Each Segment", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
